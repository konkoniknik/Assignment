# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("CUDA devices:", torch.cuda.device_count())
print("Current device:", torch.cuda.current_device())
print("Device name:", torch.cuda.get_device_name(0))  # Replace 0 with another index if needed
# Out:
# CUDA available: True
# CUDA devices: 1
# Current device: 0
# Device name: NVIDIA GeForce RTX 4050 Laptop GPU

# %%
import spacy

# Load a SpaCy English model with NER capabilities
# Choose one:
# nlp = spacy.load("en_core_web_sm")
nlp = spacy.load("en_core_web_trf")  # Larger model, better accuracy if GPU is available

# Assume you already have the 'normalize_raw_text' function and NON_WRITER_KEYWORDS from the previous solution
# as well as any other helper functions like `is_publisher_or_non_writer` and `normalize_name`.

def filter_with_ner(cleaned_text: str) -> str:
    """
    After the initial rule-based cleaning, this function uses SpaCy NER to 
    ensure that we only keep PERSON entities from the cleaned_text.
    """
    # The cleaned_text is something like "Justyce Kaseem Wright/Abdou Gambetta"
    if not cleaned_text:
        return ""
    
    # Split by '/' to process each candidate name
    candidates = [c.strip() for c in cleaned_text.split('/') if c.strip()]
    
    final_entities = []
    for candidate in candidates:
        # Use SpaCy to detect named entities
        doc = nlp(candidate)
        
        # If SpaCy doesn't identify the name as a PERSON, we may consider it non-writer (or we can fallback to heuristics)
        person_count = 0
        for ent in doc.ents:
            if ent.label_ == "PERSON":
                person_count += 1
        
        # Heuristic: If at least one PERSON entity is found in candidate, we keep it.
        # This can be refined further, for example if candidate has multiple entities and you want all to be PERSON.
        if person_count > 0:
            final_entities.append(candidate)
    
    # Join remaining entities with '/'
    return "/".join(final_entities)


def advanced_normalize_raw_text(raw_text: str) -> str:
    """
    This function first applies the previous rule-based normalization, then refines it using NER.
    """
    # Step 1: Use your previous solution to get an initial cleaned/filtered text
    #initial_cleaned = normalize_raw_text(raw_text)  # from your previously implemented code
    
    # Step 2: Apply NER-based filtering
    final_cleaned = filter_with_ner(raw_text)#initial_cleaned)
    
    return final_cleaned

# ------------------ Example Testing ------------------

example1 = "<Unknown>/Wright, Justyce Kaseem"
example2 = "Pixouu/Abdou Gambetta/Copyright Control"
example3 = "Mike Hoyer/JERRY CHESNUT/SONY/ATV MUSIC PUBLISHING (UK) LIMITED"

print("Example 1:")
print("RAW:", example1)
print("After Rule-based:", normalize_raw_text(example1))
print("After NER-based:", advanced_normalize_raw_text(example1))
print()

print("Example 2:")
print("RAW:", example2)
print("After Rule-based:", normalize_raw_text(example2))
print("After NER-based:", advanced_normalize_raw_text(example2))
print()

print("Example 3:")
print("RAW:", example3)
print("After Rule-based:", normalize_raw_text(example3))
print("After NER-based:", advanced_normalize_raw_text(example3))
print()

# %%
import pandas as pd
import re

# Example filtering keywords that indicate non-writer entities:
NON_WRITER_KEYWORDS = [
    "unknown", "copyright", "control", "publishing", "music", "records",
    "limited", "ltd", "universal", "warner", "sony", "bmg", "ascap", "bmi", "socan"
]

def is_publisher_or_non_writer(entity: str) -> bool:
    # Check if the entity contains any of the known non-writer keywords
    # We do a case-insensitive check
    entity_lower = entity.lower()
    return any(keyword in entity_lower for keyword in NON_WRITER_KEYWORDS)

def normalize_name(name: str) -> str:
    # If the name is in format "Lastname, Firstname ..."
    # Convert it to "Firstname ... Lastname"
    name = name.strip()
    if "," in name:
        parts = [p.strip() for p in name.split(",")]
        if len(parts) == 2:
            lastname, firstname = parts
            # Convert to title case:
            firstname_tokens = [t.capitalize() for t in firstname.split()]
            lastname_tokens = [t.capitalize() for t in lastname.split()]
            # Reassemble as "Firstname ... Lastname"
            name = " ".join(firstname_tokens + lastname_tokens)
        else:
            # In case of multiple commas (rare)
            # E.g., "Wright, Justyce Kaseem" should just handle 1 comma.
            # If multiple commas appear, handle gracefully:
            # Assume last part is lastname, rest is firstname/middle:
            lastname = parts[0]
            firstname_middle = " ".join(parts[1:])
            firstname_middle_tokens = [t.capitalize() for t in firstname_middle.split()]
            lastname_tokens = [t.capitalize() for t in lastname.split()]
            name = " ".join(firstname_middle_tokens + lastname_tokens)
    else:
        # No comma, just title case the whole name
        name_tokens = [t.capitalize() for t in name.split()]
        name = " ".join(name_tokens)
    return name

def normalize_raw_text(raw_text: str) -> str:
    # Split by "/"
    entities = [e.strip() for e in raw_text.split("/") if e.strip()]

    # Filter out non-writer entities
    writer_candidates = [e for e in entities if not is_publisher_or_non_writer(e)]

    # Normalize each writer candidate name
    normalized_names = [normalize_name(w) for w in writer_candidates]

    # Join back with "/"
    normalized_text = "/".join(normalized_names)
    return normalized_text

# ------------------ Example Testing ------------------
example1 = "<Unknown>/Wright, Justyce Kaseem"
example2 = "Pixouu/Abdou Gambetta/Copyright Control"
example3 = "Mike Hoyer/JERRY CHESNUT/SONY/ATV MUSIC PUBLISHING (UK) LIMITED"

print("Example 1:")
print("RAW:", example1)
print("Normalized:", normalize_raw_text(example1))
print()

print("Example 2:")
print("RAW:", example2)
print("Normalized:", normalize_raw_text(example2))
print()

print("Example 3:")
print("RAW:", example3)
print("Normalized:", normalize_raw_text(example3))
print()

# ------------------ Processing a Dataset ------------------
# Suppose we have a CSV with columns: raw_comp_writers_text, CLEAN_TEXT
# We apply the normalization to raw_comp_writers_text and compare with CLEAN_TEXT

# df = pd.read_csv('path_to_dataset.csv')
# df['PREDICTED_CLEAN_TEXT'] = df['raw_comp_writers_text'].apply(normalize_raw_text)

# Evaluate or inspect a few rows
# print(df.head())
# Out:
# Example 1:
# RAW: <Unknown>/Wright, Justyce Kaseem
# Normalized: Justyce Kaseem Wright
#
# Example 2:
# RAW: Pixouu/Abdou Gambetta/Copyright Control
# Normalized: Pixouu/Abdou Gambetta
#
# Example 3:
# RAW: Mike Hoyer/JERRY CHESNUT/SONY/ATV MUSIC PUBLISHING (UK) LIMITED
# Normalized: Mike Hoyer/Jerry Chesnut

# %%
import spacy

# Load a SpaCy English model with NER capabilities
# Choose one:
# nlp = spacy.load("en_core_web_sm")
nlp = spacy.load("en_core_web_trf")  # Larger model, better accuracy if GPU is available

# Assume you already have the 'normalize_raw_text' function and NON_WRITER_KEYWORDS from the previous solution
# as well as any other helper functions like `is_publisher_or_non_writer` and `normalize_name`.

def filter_with_ner(cleaned_text: str) -> str:
    """
    After the initial rule-based cleaning, this function uses SpaCy NER to 
    ensure that we only keep PERSON entities from the cleaned_text.
    """
    # The cleaned_text is something like "Justyce Kaseem Wright/Abdou Gambetta"
    if not cleaned_text:
        return ""
    
    # Split by '/' to process each candidate name
    candidates = [c.strip() for c in cleaned_text.split('/') if c.strip()]
    
    final_entities = []
    for candidate in candidates:
        # Use SpaCy to detect named entities
        doc = nlp(candidate)
        
        # If SpaCy doesn't identify the name as a PERSON, we may consider it non-writer (or we can fallback to heuristics)
        person_count = 0
        for ent in doc.ents:
            if ent.label_ == "PERSON":
                person_count += 1
        
        # Heuristic: If at least one PERSON entity is found in candidate, we keep it.
        # This can be refined further, for example if candidate has multiple entities and you want all to be PERSON.
        if person_count > 0:
            final_entities.append(candidate)
    
    # Join remaining entities with '/'
    return "/".join(final_entities)


def advanced_normalize_raw_text(raw_text: str) -> str:
    """
    This function first applies the previous rule-based normalization, then refines it using NER.
    """
    # Step 1: Use your previous solution to get an initial cleaned/filtered text
    #initial_cleaned = normalize_raw_text(raw_text)  # from your previously implemented code
    
    # Step 2: Apply NER-based filtering
    final_cleaned = filter_with_ner(raw_text)#initial_cleaned)
    
    return final_cleaned

# ------------------ Example Testing ------------------

example1 = "<Unknown>/Wright, Justyce Kaseem"
example2 = "Pixouu/Abdou Gambetta/Copyright Control"
example3 = "Mike Hoyer/JERRY CHESNUT/SONY/ATV MUSIC PUBLISHING (UK) LIMITED"

print("Example 1:")
print("RAW:", example1)
print("After Rule-based:", normalize_raw_text(example1))
print("After NER-based:", advanced_normalize_raw_text(example1))
print()

print("Example 2:")
print("RAW:", example2)
print("After Rule-based:", normalize_raw_text(example2))
print("After NER-based:", advanced_normalize_raw_text(example2))
print()

print("Example 3:")
print("RAW:", example3)
print("After Rule-based:", normalize_raw_text(example3))
print("After NER-based:", advanced_normalize_raw_text(example3))
print()
# Out:
# c:\Users\konni\venv\Lib\site-packages\thinc\shims\pytorch.py:261: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filelike, map_location=device))
# Example 1:
# RAW: <Unknown>/Wright, Justyce Kaseem
# After Rule-based: Justyce Kaseem Wright
# After NER-based: Wright, Justyce Kaseem
#
# Example 2:
# RAW: Pixouu/Abdou Gambetta/Copyright Control
# After Rule-based: Pixouu/Abdou Gambetta
# After NER-based: Pixouu/Abdou Gambetta
#
# Example 3:
# RAW: Mike Hoyer/JERRY CHESNUT/SONY/ATV MUSIC PUBLISHING (UK) LIMITED
# After Rule-based: Mike Hoyer/Jerry Chesnut
# After NER-based: Mike Hoyer/JERRY CHESNUT/SONY

# %%
import pandas as pd
from collections import Counter
import re


def split_keep_phrases_dynamic(text, separation='weak'):
    if not text or not isinstance(text, str):
        return []  # Return an empty list for invalid or empty input

    # Identify non-alphanumeric separators (escaping used for handling re symbols)
    if separation == 'strong':
        # More general separation using collection of separators
        separators = ''.join([re.escape(char) for char, _ in Counter(text).items() if not char.isalnum() and char.strip()])
    else:
        # Weaker separation based on the data
        separators_list = '/&,()'#()'
        separators = ''.join([re.escape(char) for char in separators_list if not char.isalnum() and char.strip()])

    # Debugging: Log separators to ensure they're valid
    if not separators:
        print(f"No valid separators found in: {text}")
        return [text.strip()]  # Return the original text as a single phrase

    try:
        # Build regex to split on these separators (excluding spaces)
        regex = f"[{separators}]+"
        
        # Split the text while keeping phrases together
        parts = re.split(regex, text)
        return [part.strip() for part in parts if part.strip()]
    except re.error as e:
        # Log regex error for debugging
        print(f"Regex error with separators '{separators}' for text: {text}. Error: {e}")
        return [text.strip()]  # Return the original text as a fallback



# Read the Excel file
file_path = "data/raw/normalization_assesment_dataset_10k.csv"  
df = pd.read_csv(file_path)

# Apply the splitting function to the 'raw_comp_writers_text' column
df['split_phrases'] = df['raw_comp_writers_text'].apply(lambda x: split_keep_phrases_dynamic(x,separation='strong') if pd.notnull(x) else [])

# Save the updated DataFrame to a new Excel file
output_file_path = "output_file.csv"  
df.to_csv(output_file_path, index=False)

print(f"Processed data has been saved to {output_file_path}")
# Out:
# No valid separators found in: Martin Hygård
# No valid separators found in: Mendel Brikman
# No valid separators found in: Alvin Lee
# No valid separators found in: Mefi Morales
# No valid separators found in: Christopher Franke
# No valid separators found in: Shashank Katkar
# No valid separators found in: Mike Kalambay
# No valid separators found in: Rikard Sjöblom
# No valid separators found in: Junior Francisco
# No valid separators found in: PHUC TRUONG
# No valid separators found in: Slatt Zy
# No valid separators found in: Ivan Torrent
# No valid separators found in: An Stepper
# No valid separators found in: fo man
# No valid separators found in: Traditional
# No valid separators found in: Christian Michelle Felix Felix
# No valid separators found in: Eric Andersen
# No valid separators found in: Efrem Jamaar Blackwell
# No valid separators found in: Ludwig van Beethoven
# No valid separators found in: Nguyễn Nhất Huy
# No valid separators found in: Hayden Buck Jones
# No valid separators found in: Alexey Abrosimov
# No valid separators found in: Bhai Gurbachan Singh Ji Sri Ganganagar Wale
# No valid separators found in: Mozzy
# No valid separators found in: Angel Graciano
# No valid separators found in: AARON D SPRINKLE
# No valid separators found in: Danny Kortchmar
# No valid separators found in: Johann Sebastian Bach
# No valid separators found in: Donovan Edjuan Jarrett
# No valid separators found in: Horace Watt
# No valid separators found in: Joseph Haydn
# No valid separators found in: Willie Taylor
# No valid separators found in: Khúc Lan
# No valid separators found in: Dhibu Ninan Thomas
# No valid separators found in: Lil Durk
# No valid separators found in: Tomaso Albinoni
# No valid separators found in: Akshay Roy
# No valid separators found in: Aleksandr Alekseevich Osipov
# No valid separators found in: Sam Geiser
# No valid separators found in: Ray Davies
# No valid separators found in: Auditory Music
# No valid separators found in: Zeke N Moon
# No valid separators found in: Dorian Guerra
# No valid separators found in: BMI
# No valid separators found in: Leandro Baron Utria
# No valid separators found in: Pete Townshend
# No valid separators found in: Jeff Moise Right
# No valid separators found in: Pablo Milanés
# No valid separators found in: Helena Hauff
# No valid separators found in: Max Cameron Concors
# No valid separators found in: Jung Sik Kong
# No valid separators found in: Michael Hoenig
# No valid separators found in: 0
# No valid separators found in: Darren Malic Carr
# No valid separators found in: Revan
# No valid separators found in: Baps Swaminarayan Sanstha
# No valid separators found in: zts
# No valid separators found in: Liam Barcelo
# No valid separators found in: Irma Pany
# No valid separators found in: Dai Matsuda
# No valid separators found in: Danny Wong
# No valid separators found in: Sasha Sharipov
# No valid separators found in: Benito Rodriguez
# No valid separators found in: Gaetano Donizetti
# No valid separators found in: Jimmy Lewis
# No valid separators found in: Satoshi Iwamizu
# No valid separators found in: Chitsanupong Lex
# No valid separators found in: Richard Wagner
# No valid separators found in: Ba San Yao A Pu
# No valid separators found in: Dmitriy Malikov
# No valid separators found in: Кулаков Олег
# No valid separators found in: Kirill Ruslanovich Timoshenko
# No valid separators found in: Fernando Borrego Linares
# No valid separators found in: John Easdale
# No valid separators found in: Back on Track Records
# No valid separators found in: Jessie Clay
# No valid separators found in: Salomon Salil Lira
# No valid separators found in: Álvaro Carillo
# No valid separators found in: Ольга Пулатова
# No valid separators found in: UNKNOWN WRITER
# No valid separators found in: Nikolay Kirimeli
# No valid separators found in: Henry Desmarest
# No valid separators found in: Gwenifer Raymond
# No valid separators found in: Nova Rockafeller
# No valid separators found in: John Cannon
# No valid separators found in: Карпов Ярослав Максимович
# No valid separators found in: Prince Sole
# No valid separators found in: Brad Roberts
# No valid separators found in: Claude Debussy
# No valid separators found in: Baby Ru
# No valid separators found in: Justin Hayward
# No valid separators found in: Abshari Afghani
# No valid separators found in: Kodak Black
# No valid separators found in: Casey Hizer
# No valid separators found in: Dagirov Dagir
# No valid separators found in: Q luv
# No valid separators found in: Nacho Cano
# No valid separators found in: Dan Hylander
# No valid separators found in: Akira Ifukube
# No valid separators found in: Phạm Đăng Khương
# No valid separators found in: Robert Din Barbulesti
# No valid separators found in: Tyvel Dixon
# No valid separators found in: Anonymous
# No valid separators found in: Steve Miller
# No valid separators found in: Joe Brook
# No valid separators found in: Eric Xavier claros
# No valid separators found in: Nik Hamedi
# No valid separators found in: Isaac Hall
# No valid separators found in: Edson Zuñiga
# No valid separators found in: StanWill
# No valid separators found in: Nellie McKay
# No valid separators found in: 김우근
# No valid separators found in: 藤江潤士
# No valid separators found in: Jobete Music Co Inc
# No valid separators found in: Dewayne Dabney
# No valid separators found in: Nestor Daniel Hoyer
# No valid separators found in: Antonio Vivaldi
# No valid separators found in: Pyotr Ilyich Tchaikovsky
# No valid separators found in: SayWeCanFly
# No valid separators found in: Mbosso
# No valid separators found in: Josquin Des Prez
# No valid separators found in: Jesper Kyd
# No valid separators found in: Justin McDonald
# No valid separators found in: Alfredo Lopez
# No valid separators found in: VCPMC
# No valid separators found in: Tasuku Kashiwagi
# No valid separators found in: Kala Sangam
# No valid separators found in: Marcus D
# No valid separators found in: Avi Rosenfeld
# No valid separators found in: Dave Mustaine
# No valid separators found in: Mansij Madaan
# No valid separators found in: AFPI
# No valid separators found in: James Joshua Otto
# No valid separators found in: Robin Ogden
# No valid separators found in: Hanawa
# No valid separators found in: Nicolás Urquiza
# No valid separators found in: Harry Beckett
# No valid separators found in: Jesse Colin Young
# No valid separators found in: Harmonize
# No valid separators found in: Whobody Publishing
# No valid separators found in: Randy Bachman
# No valid separators found in: Heitor Pereira
# No valid separators found in: Percy Mayfield
# No valid separators found in: WREN MUSIC CO
# No valid separators found in: JOSE DEL CARMEN GARABITA MURAN
# No valid separators found in: Andrew Gold
# No valid separators found in: Sipili Nanai
# No valid separators found in: John Lennon
# No valid separators found in: David Tesar
# No valid separators found in: Soziedad Alkoholika
# No valid separators found in: Nahúm Francisco Peláez Mariano
# No valid separators found in: BoofPaxkMooky
# No valid separators found in: Daniel Parrilla
# No valid separators found in: Jack Stauber
# No valid separators found in: Agustín Lara
# No valid separators found in: Norma Pelico
# No valid separators found in: Ric Ocasek
# No valid separators found in: Jerrell Bailey
# No valid separators found in: Ferruccio Busoni
# No valid separators found in: Richard Melville Hall
# No valid separators found in: Lisandro Meza
# No valid separators found in: Nhật Trung
# No valid separators found in: Karen Itzel Sanchez
# No valid separators found in: Rubeinstein McClure
# No valid separators found in: Kevin Gates
# No valid separators found in: GetRichZay
# No valid separators found in: Blind Lemon Jefferson
# No valid separators found in: Dianer Moreno Betancourth
# No valid separators found in: lexo
# No valid separators found in: Goblin Mixes
# No valid separators found in: 李斌
# No valid separators found in: Morty Shad
# No valid separators found in: Олег Скобля
# No valid separators found in: Madalyn Simon
# No valid separators found in: Mario Javier Coto
# No valid separators found in: Wyatt Towler
# No valid separators found in: Nathan William Hose
# No valid separators found in: Premo Rice
# No valid separators found in: Yanko Rojas Mena
# No valid separators found in: Dominic Angas
# No valid separators found in: Rich the Factor
# No valid separators found in: Seyi Vibez
# No valid separators found in: Nil Moliner
# No valid separators found in: Pedro Murart
# No valid separators found in: Warner Chappell
# No valid separators found in: Irisvaldo Silva
# No valid separators found in: Ciro Paniagua
# No valid separators found in: Megalodon
# No valid separators found in: Lukas Stütz
# No valid separators found in: Brad Michael Tukes
# No valid separators found in: 김창환
# No valid separators found in: Elijah Lewis
# No valid separators found in: Tasleem Fazli
# No valid separators found in: Lloyd James Jr
# No valid separators found in: Ebenezer Obey
# No valid separators found in: Jim Brickman
# No valid separators found in: Queen Key
# No valid separators found in: Scott Fitzgerald
# No valid separators found in: Hi Power
# No valid separators found in: Kevin L Barnes
# No valid separators found in: Patrick Hawes
# No valid separators found in: 徐朗
# No valid separators found in: Ethan Gluis
# No valid separators found in: Kedrick Rodiguez Anguiano
# No valid separators found in: ビッケブランカ
# No valid separators found in: Arthur Nery
# No valid separators found in: Jissel Shaddai Carvajalino Acosta
# No valid separators found in: Los Zultannes del Norte
# No valid separators found in: Kevin Dejean
# No valid separators found in: MacRae
# No valid separators found in: Lou Reed
# No valid separators found in: Naoto Kubo
# No valid separators found in: Chick Corea
# No valid separators found in: Fryderyk Chopin
# No valid separators found in: Isaiam
# No valid separators found in: Todd Christensen
# No valid separators found in: Trương Quang Tuấn
# No valid separators found in: Evandro Santos
# No valid separators found in: Andrea Ronchi
# No valid separators found in: Btg Bug
# No valid separators found in: Sutton Kelley
# No valid separators found in: Aaron Hernandez
# No valid separators found in: José Barros
# No valid separators found in: BIGBAND Entertainment
# No valid separators found in: Борисенко Савелий Витальевич
# No valid separators found in: Kuma the Third
# No valid separators found in: MERCER CHRISTOPHER WILLIAM
# No valid separators found in: Penyair
# No valid separators found in: Clarken Orosco
# No valid separators found in: Profit Child
# No valid separators found in: David Gray
# No valid separators found in: Bobomurod Soginboev
# No valid separators found in: Vincent Clarke
# No valid separators found in: Okay  Temiz
# No valid separators found in: Shaun Fleming
# No valid separators found in: Jose Ontiveros Meza
# No valid separators found in: Phora
# No valid separators found in: AFN Peso
# No valid separators found in: Lil Rob
# No valid separators found in: Abelenda Mena
# No valid separators found in: Rayburn Anderson
# No valid separators found in: Carlos Eldrako jones jr
# No valid separators found in: Ирина Дубцова
# No valid separators found in: Luc De Vos
# No valid separators found in: Johannes Brahms
# No valid separators found in: Miles Davis
# No valid separators found in: copyright control
# No valid separators found in: Airam Paez
# No valid separators found in: Bedřich Smetana
# No valid separators found in: Wolfgang Amadeus Mozart
# No valid separators found in: Julia Jacklin
# No valid separators found in: Slajf Slajfsson
# No valid separators found in: Mammad Ibrahimov
# No valid separators found in: Ben Prokopowicz
# No valid separators found in: Luigi Rossi
# No valid separators found in: joan sebastian sebastian
# No valid separators found in: Shalosh
# No valid separators found in: RMC Mike
# No valid separators found in: Blackboi Draco
# No valid separators found in: 植松伸夫
# No valid separators found in: Gulshan Sharma
# No valid separators found in: Maurice Ravel
# No valid separators found in: Big Sad 1900
# No valid separators found in: Phil Collins
# No valid separators found in: ZAMUDIO SANTOS CASIMIRO
# No valid separators found in: Ariel
# No valid separators found in: Emily Cheng
# No valid separators found in: Curtis Humphrey
# No valid separators found in: Chris Isaak
# No valid separators found in: Matt Ingram
# No valid separators found in: Thomas Bergersen
# No valid separators found in: juan Fernando alonso ortiz
# No valid separators found in: Koh Sangji
# No valid separators found in: Mario Quintero Lara
# No valid separators found in: Joe Resnek
# No valid separators found in: Bruce Springsteen
# No valid separators found in: AJ DiSpirito
# No valid separators found in: Efrain Canan
# No valid separators found in: Rob Hubbard
# No valid separators found in: John McCoy
# No valid separators found in: Darrell Frison
# No valid separators found in: Xu Wei
# No valid separators found in: Vingo Regino
# No valid separators found in: Clayton Maselle
# No valid separators found in: VICTOR YOUNG
# No valid separators found in: Phil Caivano
# No valid separators found in: Jose Castellon
# No valid separators found in: Hoài Loan
# No valid separators found in: Esa Ruoho
# No valid separators found in: Christopher Lennertz
# No valid separators found in: Rayons
# No valid separators found in: Julio Jaramillo
# No valid separators found in: Yelawolf
# No valid separators found in: Greg Hughes
# No valid separators found in: Jesús Alberto Luna
# No valid separators found in: Tim Meegan
# No valid separators found in: Farrux Xamrayev
# No valid separators found in: Mariano Fuertes Fernández
# No valid separators found in: Thomas Benjamin Wild Esq
# No valid separators found in: Stevens
# No valid separators found in: Jérôme Echenoz
# No valid separators found in: blake boochee
# No valid separators found in: Just Creative 111
# No valid separators found in: Trevon Williams
# No valid separators found in: Vic Ruggiero
# No valid separators found in: Deondre cloyd
# No valid separators found in: Bam Roc
# No valid separators found in: Dave Porter
# No valid separators found in: LAWTON WILLIAM FRANCIS
# No valid separators found in: Sean Jacobs
# No valid separators found in: Emmanuel Carpus
# No valid separators found in: Trequis Dickson
# No valid separators found in: Moreao
# No valid separators found in: Sana Tajik
# No valid separators found in: Elijah Dunham
# No valid separators found in: Nathalie Joachim
# No valid separators found in: Giacomo Meyerbeer
# No valid separators found in: UNKNOWN
# No valid separators found in: Francisco Gómez El Nuevo Rey De La Música Popular
# No valid separators found in: Konrad Carelli
# No valid separators found in: Lil Lonnie
# No valid separators found in: Copyright Control
# No valid separators found in: Neru
# No valid separators found in: Marvin Gaye
# No valid separators found in: Tess Gerritsen
# No valid separators found in: WIBERT CHRISTER LENNART
# No valid separators found in: DEMETRIUS TERRY
# No valid separators found in: Standing Egg
# No valid separators found in: Dương Thụ
# No valid separators found in: Ashley Simon
# No valid separators found in: Dave Matthews
# No valid separators found in: David Newlyn
# No valid separators found in: Ben Chandler
# No valid separators found in: Blé Marius
# No valid separators found in: Joel Santibañez
# No valid separators found in: Saifoulaye Balde
# No valid separators found in: Night Lovell
# No valid separators found in: Charles MacPherson
# No valid separators found in: Jenn Carter
# No valid separators found in: Chuck Berry
# No valid separators found in: Tre Lee
# No valid separators found in: Charles Ans
# No valid separators found in: Xuân Mỹ
# No valid separators found in: Sadhu Sarvatitdas
# No valid separators found in: Roc Chen
# No valid separators found in: Shiro SAGISU
# No valid separators found in: Jeff Tweedy
# No valid separators found in: Marketa Irglova
# No valid separators found in: Takafumi Imamura
# No valid separators found in: Khvan Roman
# No valid separators found in: Gandzha Dmitrii Andreevich
# No valid separators found in: CRYSTAL YATES
# No valid separators found in: Solitario
# No valid separators found in: Jerome Kern
# No valid separators found in: William Lee Martin
# No valid separators found in: 2sdxrt3all
# No valid separators found in: Gösta Linderholm
# No valid separators found in: Juan Ignacio Meira
# No valid separators found in: Anh Việt Thu
# No valid separators found in: William Ferris
# No valid separators found in: Musukha Goyari
# No valid separators found in: George Achieng
# No valid separators found in: Ernesto José Mora Piedra
# No valid separators found in: American Football
# No valid separators found in: Elisabeth César Blanco
# No valid separators found in: Edwin Tolosa
# No valid separators found in: Pendiente
# No valid separators found in: KraiGGi BaDArT
# No valid separators found in: Tomash Lukach
# No valid separators found in: Sdot Go
# No valid separators found in: Neru
# No valid separators found in: Neil Diamond
# No valid separators found in: Pérez Prado
# No valid separators found in: Flor Ivonne Quezada
# No valid separators found in: James Bradshaw
# No valid separators found in: Victor Ufuoma Thompson
# No valid separators found in: Leonid Forostov
# No valid separators found in: Joko Esha
# No valid separators found in: Mieczysław Karłowicz
# No valid separators found in: Myriam Alter
# No valid separators found in: Not Documented
# No valid separators found in: deko
# No valid separators found in: Peter Thomas
# No valid separators found in: Copyright Controlled
# No valid separators found in: Lil Kee
# No valid separators found in: Emanuel Dorris
# No valid separators found in: Klaus Schmidt
# No valid separators found in: Ed Cobb
# No valid separators found in: François Francoeur
# No valid separators found in: Ronela Hajati
# No valid separators found in: Juan Rogelio Smith
# No valid separators found in: MORRISON VAN
# No valid separators found in: Edvard Grieg
# No valid separators found in: Kobalt Music
# No valid separators found in: Armonian
# No valid separators found in: Leon Bolier
# No valid separators found in: Winfield Scott
# No valid separators found in: Piero Paolinelli
# No valid separators found in: Season of Mist Publishing
# No valid separators found in: Fito Páez
# No valid separators found in: Ruggero Leoncavallo
# No valid separators found in: Steve Marion
# No valid separators found in: Dan Collins
# No valid separators found in: 天野月
# No valid separators found in: Shizzo
# No valid separators found in: Dynamedion
# No valid separators found in: Ivan Dola
# No valid separators found in: Sameer
# No valid separators found in: Richard Brewster
# No valid separators found in: Катерина Єрьоменко
# No valid separators found in: Thomas Bergersen
# No valid separators found in: Litto Nebbia
# No valid separators found in: Zheng Ke Wang
# No valid separators found in: Khalif Belser
# No valid separators found in: Paul Giovanni
# No valid separators found in: Rah Swish
# No valid separators found in: Sergey Khavro
# No valid separators found in: Felix Mendelssohn
# No valid separators found in: Hector Manuel Hernandez Olmedo
# No valid separators found in: Barbara Moore
# No valid separators found in: DJ OG Uncle Skip
# No valid separators found in: Subhumans
# No valid separators found in: Elvis Barba Souto
# No valid separators found in: Gonzalo Tamames Pereira
# No valid separators found in: Mieszko Talarczyk
# No valid separators found in: Alhousseini Anivolla
# No valid separators found in: Lupe T Martinez H
# No valid separators found in: Dan Reynolds
# No valid separators found in: David Nesta Marley
# No valid separators found in: Galaxy Express
# No valid separators found in: Aman Berzhibaev
# No valid separators found in: Tory Lanez
# No valid separators found in: Peter McConnell
# No valid separators found in: Kevin Barnes
# No valid separators found in: Mory Kanté
# No valid separators found in: 北出菜奈
# No valid separators found in: Andree Kress
# No valid separators found in: Lil Skies
# No valid separators found in: John Philip Sousa
# No valid separators found in: Eric Whitney
# No valid separators found in: Jacques Brel
# No valid separators found in: Randy California
# No valid separators found in: Jarv
# No valid separators found in: Li Qi Niu
# No valid separators found in: Ivy Sole
# No valid separators found in: Gonzalo Hermosa
# No valid separators found in: Cheb Bilal
# No valid separators found in: Second Line Productions
# No valid separators found in: Morgan Rice
# No valid separators found in: Richard Wagner
# No valid separators found in: GOODMAN  JOEL SCOTT
# No valid separators found in: Nicholas Macri
# No valid separators found in: Lil Shun
# No valid separators found in: Жанышбеков Нурсултан
# No valid separators found in: Lê Hựu Hà
# No valid separators found in: Graham Russell
# No valid separators found in: Ferry Ridderhof
# No valid separators found in: Jose Antonio Ruiz
# No valid separators found in: Mahudone Silisack
# No valid separators found in: Attaullah Khan Esakhelvi
# No valid separators found in: Tiến Minh
# No valid separators found in: Tonny Tun Tun
# No valid separators found in: Junji Yoshida
# No valid separators found in: ناصر القطامي
# No valid separators found in: Hamid Tadayoni
# No valid separators found in: Branislav Laho
# No valid separators found in: Warner Chappell Music Argentina
# No valid separators found in: Kofi Wilmot
# No valid separators found in: Erin McKeown
# No valid separators found in: Connor Price
# No valid separators found in: SOLITARIO MUSICAL
# No valid separators found in: AJ Bartolucci
# No valid separators found in: Niki Reiser
# No valid separators found in: Paradosiako
# No valid separators found in: The The
# No valid separators found in: Bradley Nowell
# No valid separators found in: Manan Bhardwaj
# No valid separators found in: Only The Realest
# No valid separators found in: Jeet Gannguli
# No valid separators found in: Aleksa Safiya
# No valid separators found in: Cyraq
# No valid separators found in: KAKA
# No valid separators found in: Charmayne Perry
# No valid separators found in: tre george
# No valid separators found in: Joe Raposo
# No valid separators found in: Phạm Toàn Thắng
# No valid separators found in: Marc Bolan
# No valid separators found in: Martez Adon Drew
# No valid separators found in: SAVANA SANTOS
# No valid separators found in: Juan Gabriel
# No valid separators found in: Emily Paige Jeffrey
# No valid separators found in: BCee
# No valid separators found in: Julian Garza
# No valid separators found in: Jack Stauber
# No valid separators found in: Kouanvi Kokou
# No valid separators found in: Daniel Garcés
# No valid separators found in: 平沢進
# No valid separators found in: 米津玄師
# No valid separators found in: Jeanne Cherhal
# No valid separators found in: Johnathan Jerel Johnson
# No valid separators found in: Giuseppe Torelli
# No valid separators found in: Shiv Kumar Batalvi
# No valid separators found in: Andrii Usachov
# No valid separators found in: Jairo Varela
# No valid separators found in: CHINOZO
# No valid separators found in: Enrique Perez
# No valid separators found in: Richard Strauss
# No valid separators found in: Rohan Reid
# No valid separators found in: Joaquin Felices Celina Espada
# No valid separators found in: Eden Muñoz
# No valid separators found in: Brian Frank Hibbert
# No valid separators found in: Na
# No valid separators found in: Lam Phương
# No valid separators found in: Jack Wall
# No valid separators found in: Srinivas
# No valid separators found in: Benjamin OrtÍz HernÁndez
# No valid separators found in: John Glenn Kunkel
# No valid separators found in: ROBERTSON
# No valid separators found in: Aleksey Sakharov
# No valid separators found in: Haarper
# No valid separators found in: Bry Greatah
# No valid separators found in: Kevoy Clarke and Jack Scorpio
# No valid separators found in: 中田ヤスタカ
# No valid separators found in: Isidro Chavez Espinoza
# No valid separators found in: Sergei Prokofiev
# No valid separators found in: Chester Burnett
# No valid separators found in: Yoshimi Kudo
# No valid separators found in: Nestor Romario Rodriguez Tuexi
# No valid separators found in: Alejandro Flores
# No valid separators found in: António Pedro Neves
# No valid separators found in: Iker Calero Sanchez
# No valid separators found in: 我想喝飲料
# No valid separators found in: FENDER MILES
# No valid separators found in: KURO
# No valid separators found in: Young God
# No valid separators found in: Javoris Hollingsworth
# No valid separators found in: COPYRIGHT CONTROL SGAE
# No valid separators found in: Luke Morley
# No valid separators found in: Edson Zuñiga
# No valid separators found in: Al Schnier
# No valid separators found in: Paolo Conte
# No valid separators found in: Hank Cochran
# No valid separators found in: John Zorn
# No valid separators found in: Noah Steven Whitney
# No valid separators found in: MORALI JONATHAN
# No valid separators found in: Ibbz Awan
# No valid separators found in: Bubba Kadane
# No valid separators found in: Stephen Pishner
# No valid separators found in: Kasheme Ingram
# No valid separators found in: Ele A El Dominio
# No valid separators found in: Kabila Records
# No valid separators found in: 平井康三郎
# No valid separators found in: Elmore James
# No valid separators found in: Lilli Lewis
# No valid separators found in: Token
# No valid separators found in: SoFaygo
# No valid separators found in: Hans Zimmer
# No valid separators found in: James Tucker
# No valid separators found in: Lucille Holcomb
# No valid separators found in: Tilo Wolff
# No valid separators found in: Oumguil
# No valid separators found in: Valve
# No valid separators found in: Eddie Lavelle Jackson
# No valid separators found in: raul nadal
# No valid separators found in: Agustín Mendoza
# No valid separators found in: Dakka Hutagalung
# No valid separators found in: Jordan Sanó Novoa
# No valid separators found in: Valeriy Dayneko
# No valid separators found in: Flavio dos Teclados
# No valid separators found in: Dick Peirce
# No valid separators found in: Parra del Riego Campoverde
# No valid separators found in: Gaetano Donizetti
# No valid separators found in: Robert Schumann
# No valid separators found in: Shailesh Thakar
# No valid separators found in: Donnacha Dennehy
# No valid separators found in: Khia Chambers
# No valid separators found in: Rose Georges
# No valid separators found in: Pop Kill
# No valid separators found in: Jerry Goldsmith
# No valid separators found in: Jorge Luis Piloto
# No valid separators found in: Pan Pan
# No valid separators found in: Dan Atner
# No valid separators found in: Kfir Lankry
# No valid separators found in: John Mayall
# No valid separators found in: Andrew Collins
# No valid separators found in: Bilal Dj Bilal Aliouane
# No valid separators found in: L Blackburn
# No valid separators found in: Danny Kiranos
# No valid separators found in: Alex Goody
# No valid separators found in: Stephen Schwartz
# No valid separators found in: Susannah Baldearena
# No valid separators found in: JayDaYoungan
# No valid separators found in: Thaivox
# No valid separators found in: Trille
# No valid separators found in: Alex Charb
# No valid separators found in: Wolfgang Amadeus Mozart
# No valid separators found in: Frederick Bernard Ivey
# No valid separators found in: Young Ratchit
# No valid separators found in: Bishwo Dong
# No valid separators found in: Ben Buhler
# No valid separators found in: Muhammet Tavşanoğlu
# No valid separators found in: Ionut Bejinariu
# No valid separators found in: Dar Dar
# No valid separators found in: Victor Spinelli
# No valid separators found in: Thanh Sơn
# No valid separators found in: Pino Donaggio
# No valid separators found in: Leonard Rosenman
# No valid separators found in: Luis Enrique Lopez
# No valid separators found in: Will Stetson
# No valid separators found in: Hussain Buksh Gullo
# No valid separators found in: sam romaine
# No valid separators found in: Remember White
# No valid separators found in: MARLEY BOB
# No valid separators found in: YTB Fatt
# No valid separators found in: מלחינים שונים
# No valid separators found in: Laif Kaz
# No valid separators found in: Dayme y El High
# No valid separators found in: Boutikou Laye
# No valid separators found in: Darin Venters
# No valid separators found in: Kaj Isaksson
# No valid separators found in: Adel Nassar Nassar
# No valid separators found in: Yoodoo Park
# No valid separators found in: Văn Phụng
# No valid separators found in: Joni Mitchell
# No valid separators found in: GXNE GXNE
# No valid separators found in: BCee
# No valid separators found in: Erik Lindström
# No valid separators found in: Mick Michaels
# No valid separators found in: Jesus Eduardo Romero Ochoa
# No valid separators found in: Mc Gury
# No valid separators found in: Аршавир Мартиросян
# No valid separators found in: Sesame Workshop
# No valid separators found in: Carlos Drumond
# No valid separators found in: Orville Peck
# No valid separators found in: Tom Paxton
# No valid separators found in: Los Chunguitos
# No valid separators found in: George Frideric Handel
# No valid separators found in: Bad Bunny
# No valid separators found in: Totò Savio
# No valid separators found in: Rigo Cordova
# No valid separators found in: Costa Mee
# No valid separators found in: Scandinavianz Scandinavianz
# No valid separators found in: Ntungamili Keagile
# No valid separators found in: Tommy Strate
# No valid separators found in: Anand Bhatt
# No valid separators found in: Maximo Antonio Escaleras
# No valid separators found in: Vittorio Alfieri
# No valid separators found in: Ngọc Lễ
# No valid separators found in: Fatbabs
# No valid separators found in: Johnathan Jurone Pulliam
# No valid separators found in: K CAMP
# No valid separators found in: Yung Aura
# No valid separators found in: Куницкас Максим Сергеевич
# No valid separators found in: Meléndez Nevárez José Antonio
# No valid separators found in: SugarHill Ddot
# No valid separators found in: Nino Tempo
# No valid separators found in: KeDarius Stampley
# No valid separators found in: Rafael Garcia Duran
# No valid separators found in: Jalon Dante Paul
# No valid separators found in: Emira Zaghouani
# No valid separators found in: Rigoberto Flores
# No valid separators found in: Torsten Pröfrock
# No valid separators found in: Paul Buckmaster
# No valid separators found in: Jamal Reid
# No valid separators found in: Claudia Alexandra Madriz Meza
# No valid separators found in: Vincenzo Moccia
# No valid separators found in: Alfred Moore Thomas III
# No valid separators found in: Dennis Ferrer
# No valid separators found in: Myint Moe Aung
# No valid separators found in: German Tayum
# No valid separators found in: José Ramón Sánchez López
# No valid separators found in: Vaughn Horton
# No valid separators found in: Maximus Klein
# No valid separators found in: Zoltán Kodály
# No valid separators found in: Zander Sweeney
# No valid separators found in: Desiigner
# No valid separators found in: Enrique Guzman
# No valid separators found in: Андрей Макаревич
# No valid separators found in: JJ Doom
# No valid separators found in: Magdaleno Oliva
# No valid separators found in: Decolonize Your Mind Society
# No valid separators found in: Rodolfo de la Garza
# No valid separators found in: Dyzzen Brown
# No valid separators found in: Nathaniel Pierre Jones
# No valid separators found in: Baba Banta Singh Ji MundaPind Wale
# No valid separators found in: Giovanni Bottesini
# No valid separators found in: Erik Landskov
# No valid separators found in: Lee Arthur Taylor
# No valid separators found in: Oleg Nechiporenko
# No valid separators found in: 増岡郷太
# No valid separators found in: Mykola Mozhovyj
# No valid separators found in: Nick Arnold
# No valid separators found in: Erick Alonzo
# No valid separators found in: Orlando Watson
# No valid separators found in: Baba Gulab Singh Ji
# No valid separators found in: Min sung jin
# No valid separators found in: Matthew Hopkins
# No valid separators found in: Lê Hựu Hà
# No valid separators found in: Anna Mahas Williams
# No valid separators found in: Serhii Solovii
# No valid separators found in: Joash Nyamongo Ongechi
# No valid separators found in: Blessid Union of Souls
# No valid separators found in: Rosalía Viviana
# No valid separators found in: Drake
# No valid separators found in: Plaid
# No valid separators found in: Ignacio de Pablo
# No valid separators found in: Tostão Sanfoneiro
# No valid separators found in: Irving Isai Puerto Ramirez
# No valid separators found in: Shohei Narabe
# No valid separators found in: 鷺巣詩郎
# No valid separators found in: Shlomo Sternberg
# No valid separators found in: Alex Ross
# No valid separators found in: Colby Priest
# No valid separators found in: Brian Carroll
# No valid separators found in: Carson Fanny
# No valid separators found in: Vincenzo Avitabile
# No valid separators found in: Song Ngọc
# No valid separators found in: Pedro Escalante
# No valid separators found in: Capital
# No valid separators found in: Riza Penjoel
# No valid separators found in: Juliana Richer Daily
# No valid separators found in: Yuvan Shankar Raja
# No valid separators found in: James Everingham
# No valid separators found in: David Sylvian
# No valid separators found in: Alexis Lopez
# No valid separators found in: Serdar Ayyıldız
# No valid separators found in: Marin Marais
# No valid separators found in: Francesco Manfredini
# No valid separators found in: Eric Figueroa
# No valid separators found in: Sickboyrari
# No valid separators found in: Nikolay Miaskovsky
# No valid separators found in: Nikol Mammou Nounies
# No valid separators found in: fiona slattery
# No valid separators found in: 浜渦正志
# No valid separators found in: Terre Roche
# No valid separators found in: CORBAL Music Publishing
# No valid separators found in: Nixon Peter
# No valid separators found in: Bradley Amick
# No valid separators found in: Abraham Vazquez
# No valid separators found in: Dieter Bohlen
# No valid separators found in: Dopebwoy
# No valid separators found in: Theo Martins
# No valid separators found in: Sami Hazinses
# No valid separators found in: 綴
# No valid separators found in: Enrique Perez
# No valid separators found in: Ketil Bjørnstad
# No valid separators found in: Black Irish
# No valid separators found in: Malhi Jarnail
# No valid separators found in: Rub Amaya
# No valid separators found in: Traditional Song
# No valid separators found in: Carlos Cres
# No valid separators found in: Abdel Karim Mahyoob
# No valid separators found in: DJ Rafa
# No valid separators found in: Andrés Calamaro
# No valid separators found in: STAINSBY GREG JOHN
# No valid separators found in: Aiden Michael Overman
# No valid separators found in: Berkki Serkkunen
# No valid separators found in: Hannes Bachmeier
# No valid separators found in: Texako
# No valid separators found in: Comedy Central Records
# No valid separators found in: Шабуров Артур Васильевич
# No valid separators found in: Gilbert de Berneville
# No valid separators found in: Dane Anders Benson
# No valid separators found in: Francisco Lozano
# No valid separators found in: もんたよしのり
# No valid separators found in: Swifty Blue
# No valid separators found in: Antonín Dvořák
# No valid separators found in: Huỳnh Anh
# No valid separators found in: Ola Magnell
# No valid separators found in: Al Quran
# No valid separators found in: Ramsinh Rathod
# No valid separators found in: PEDROZA PATRICIA J
# No valid separators found in: Sauce Walka
# No valid separators found in: Samar Jackson
# No valid separators found in: Rabindranath Tagore
# No valid separators found in: Filipe Sousa
# No valid separators found in: Stan Webb
# No valid separators found in: Daniel James
# No valid separators found in: Jess Klein
# No valid separators found in: Diego Colquhoun
# No valid separators found in: Giuseppe Verdi
# No valid separators found in: Hee Young
# No valid separators found in: Javier Moreno Padilla
# No valid separators found in: Jon English
# No valid separators found in: Sean Links
# No valid separators found in: Georg Philipp Telemann
# No valid separators found in: Rodolfo Olivares
# No valid separators found in: Lyle Mays
# No valid separators found in: RR
# No valid separators found in: Marc Francois
# No valid separators found in: Alf Terje Hana
# No valid separators found in: 최갑원
# No valid separators found in: Shemarr Green
# No valid separators found in: Sonny Boy Williamson
# No valid separators found in: Caleb Hyles
# No valid separators found in: Manu Chao
# No valid separators found in: Daniel Denton
# No valid separators found in: Jordan Micah Lunsford
# No valid separators found in: Daniel Calveti
# No valid separators found in: Shibayan
# No valid separators found in: Arcangelo Corelli
# No valid separators found in: Merle Haggard
# No valid separators found in: Colin Stetson
# No valid separators found in: finkha selenia
# No valid separators found in: Quinton Deon Lee
# No valid separators found in: Maksim Klimovich
# No valid separators found in: PHILLIPS GORDON MURPHY MR
# No valid separators found in: Seryoja
# No valid separators found in: Kora
# No valid separators found in: Nguyễn Hưng
# No valid separators found in: TZ da Coronel
# No valid separators found in: Juan Atkins
# No valid separators found in: Sghenny
# No valid separators found in: Gabriela Rocha
# No valid separators found in: Samuel Karl Bohn
# No valid separators found in: Terence Kimble
# No valid separators found in: Ray Charles
# No valid separators found in: Ernesto Gonzalez Jimenez
# No valid separators found in: Matt Gray
# No valid separators found in: Anonymous
# No valid separators found in: Paublino Vargas Jimenez
# No valid separators found in: José Méndez
# No valid separators found in: Joe Zawinul
# No valid separators found in: Policarpio Rodriguez
# No valid separators found in: James Clegg
# No valid separators found in: Margus Kliimask
# No valid separators found in: Giorgos Moukidis
# No valid separators found in: Helltrain
# No valid separators found in: Anónimo
# No valid separators found in: Joriah Kwame Fleming
# No valid separators found in: Romee
# No valid separators found in: Sting
# No valid separators found in: Marco Antonio Solís
# No valid separators found in: Hoàng Thi Thơ
# No valid separators found in: Barrington Pheloung
# No valid separators found in: Onpa Music
# No valid separators found in: Paul Heyman
# No valid separators found in: 2yay
# No valid separators found in: Logic
# No valid separators found in: SadSvit
# No valid separators found in: Sergei Prokofiev
# No valid separators found in: Moussa Diallo
# No valid separators found in: Robin Williamson
# No valid separators found in: Nostromo
# No valid separators found in: Toby Fox
# No valid separators found in: HAKIM ARTESH
# No valid separators found in: Yosuke Eguchi
# No valid separators found in: Alma Cook
# No valid separators found in: Georg Böhm
# No valid separators found in: Sean Feucht
# No valid separators found in: Carl Maria von Weber
# No valid separators found in: Chris Bay
# No valid separators found in: William DeVaughn
# No valid separators found in: Chris Echols
# No valid separators found in: Y COAST
# No valid separators found in: Enigmanic
# No valid separators found in: Devilish Trio
# No valid separators found in: Cauã Erick
# No valid separators found in: Robert Broberg
# No valid separators found in: Edgar Daniel Rodriguez Sotelo
# No valid separators found in: David Bowie
# No valid separators found in: Alban Berg
# No valid separators found in: Lil 2z
# No valid separators found in: Oleg Nechiporenko
# No valid separators found in: William P Tuang
# No valid separators found in: Sub Bass Monster
# No valid separators found in: Roger Waters
# No valid separators found in: Lil Loaded
# No valid separators found in: Balbino Medellín
# No valid separators found in: CAVANAGH DANIEL
# No valid separators found in: Ambrosio Ramos
# No valid separators found in: CHAVEZ ESPINOZA ISIDRO
# No valid separators found in: Tyrek Kareem Rush
# No valid separators found in: Cuco Sánchez
# No valid separators found in: Billy Joel
# No valid separators found in: Slug
# No valid separators found in: Isidoro Berrocal
# No valid separators found in: Tah Poe Chi
# No valid separators found in: Chris Whitley
# No valid separators found in: Γιώργος Κοντραφούρης
# No valid separators found in: Giovanni Battista Viotti
# No valid separators found in: Andrea Lazzaretti
# No valid separators found in: Keshaun Smyer
# No valid separators found in: Junior Murvin
# No valid separators found in: Sid Shyne
# No valid separators found in: Will Putney
# No valid separators found in: Afghan Dambora Melody
# No valid separators found in: Dior Valladares
# No valid separators found in: Double N
# No valid separators found in: Gregg Allman
# No valid separators found in: Bob Dylan
# No valid separators found in: hail salaam
# No valid separators found in: Mai Nguyễn
# No valid separators found in: カナコ
# No valid separators found in: Alexa Rachelle Livengood
# No valid separators found in: Case
# No valid separators found in: Sergio Kramer
# No valid separators found in: Darian Hernandez
# No valid separators found in: Peaches McIntyre
# No valid separators found in: Jerry Putter
# No valid separators found in: Myles Goodwyn
# No valid separators found in: Stef Bos
# No valid separators found in: Franz Joseph Haydn
# No valid separators found in: Elisabeth von Burgen
# No valid separators found in: José Pablo Moncayo
# No valid separators found in: Raj Ranjodh
# No valid separators found in: Majrooh Sultanpuri
# No valid separators found in: yuriko
# No valid separators found in: Miguel Gonzalez Castellanos
# No valid separators found in: Juan Quin
# No valid separators found in: Peter Baumann
# No valid separators found in: Kendarius Tucker
# No valid separators found in: Franz Schubert
# No valid separators found in: Catchybeatz
# No valid separators found in: Lữ Liên
# No valid separators found in: Been A While
# No valid separators found in: Alex Turner
# No valid separators found in: Gioachino Rossini
# No valid separators found in: Juan Carlos Cisneros
# No valid separators found in: Elsa Mbandula
# No valid separators found in: Yves Duteil
# No valid separators found in: Franz Liszt
# No valid separators found in: Ndifor Achu
# No valid separators found in: Ian Livingstone
# No valid separators found in: Tuncer Yavaş
# No valid separators found in: Chris Brown
# No valid separators found in: Franz von Suppé
# No valid separators found in: Gozo y Paz Latin Jazz Band Olivares Records
# No valid separators found in: Paulo Novaes
# No valid separators found in: Hamed Dehghani
# No valid separators found in: Peter Graham
# No valid separators found in: Ravi Pawar
# No valid separators found in: Oscar Scheller
# No valid separators found in: Elie Botbol
# No valid separators found in: Glyn Johns
# No valid separators found in: Cody Ferreria
# No valid separators found in: Takashi Yoshimatsu
# No valid separators found in: James Jackland Baker
# No valid separators found in: El Alfa
# No valid separators found in: Michael Smith
# No valid separators found in: Guillem Bergadà Tarragó
# No valid separators found in: Powfu
# No valid separators found in: Dany Brillant
# No valid separators found in: Hank Devito
# No valid separators found in: Victor Herbert
# No valid separators found in: Andres Arellano Ayala
# No valid separators found in: BossWopp
# No valid separators found in: Domenico Scarlatti
# No valid separators found in: Kydd
# No valid separators found in: Aisar Hernández Segundo
# No valid separators found in: Nikolay Lourens
# No valid separators found in: Aung Thu
# No valid separators found in: Larry June
# No valid separators found in: Oddisee
# No valid separators found in: Ashur Betsargis
# No valid separators found in: Domínio Público
# No valid separators found in: Juan Carlos Vicencio Ramirez
# No valid separators found in: Rajendra Kachru
# No valid separators found in: Daniel Castro
# No valid separators found in: Max Cameron Concors
# No valid separators found in: Alexander García
# No valid separators found in: Giao Tiên
# No valid separators found in: Se Wan Jeon
# No valid separators found in: Kenichirou Suehiro
# No valid separators found in: Rafik Nouar
# No valid separators found in: WC MUSIC CORP
# No valid separators found in: Héctor Cárcamo
# No valid separators found in: Miles Lenehan
# No valid separators found in: Adrian Gurvitz
# No valid separators found in: CA BLACKFORD LLOYD
# No valid separators found in: Phineas and Ferb
# No valid separators found in: Roger Taylor
# No valid separators found in: Bhai Gurpreet Singh Ballarwal
# No valid separators found in: your movie soundtrack
# No valid separators found in: Jalen Clemons
# No valid separators found in: Kalem Tarrant
# No valid separators found in: Pete Shelley
# No valid separators found in: PAOLO PAOLINI
# No valid separators found in: Crozet
# No valid separators found in: Diego Ortiz
# No valid separators found in: NERSHI WILLIAM J
# No valid separators found in: Alan Hawkshaw
# No valid separators found in: Red Steel Music
# No valid separators found in: Conjunto Rienda Real
# No valid separators found in: Ultra Publishing
# No valid separators found in: COPYRIGHT CONTROL
# No valid separators found in: Baby Guru
# No valid separators found in: 澤野弘之
# No valid separators found in: Glenn Cardier
# No valid separators found in: Alpha Records
# No valid separators found in: Davina Jones
# No valid separators found in: Sebastian Schilde
# No valid separators found in: Song Ngọc
# No valid separators found in: 藤澤慶昌
# No valid separators found in: Timario Love
# No valid separators found in: 陈宇鹏
# No valid separators found in: Digital Healing
# No valid separators found in: ROSA  MIGUEL
# No valid separators found in: Nicholas Pedroso
# No valid separators found in: Rare Americans
# No valid separators found in: Edward Lee
# No valid separators found in: Alexander Maverick
# No valid separators found in: PuffballsUnited
# No valid separators found in: Alexander Glazunov
# No valid separators found in: Dmitry Konstantinov
# No valid separators found in: 照井順政
# No valid separators found in: Dan Smith
# No valid separators found in: Sergey Azbel
# No valid separators found in: Mc Marry
# No valid separators found in: Teddy Williams
# No valid separators found in: Eddie Skoller
# No valid separators found in: SME TaxFree
# No valid separators found in: Mayur Nadiya
# No valid separators found in: Denys Kyshchuk
# No valid separators found in: 下村陽子
# No valid separators found in: Miguel Lopes
# No valid separators found in: Juan Guerrero
# No valid separators found in: Владимир Клявин
# No valid separators found in: Madeleine Hanlon Azar
# No valid separators found in: CA NIELSEN MICHAEL MUNCH
# No valid separators found in: Eloy Perez
# No valid separators found in: Robert Clemente Cardillo II
# No valid separators found in: Brian Patrick Kane
# No valid separators found in: Lil Ene
# No valid separators found in: Alfredo Hays Cruz
# No valid separators found in: Valjmir Abdii
# No valid separators found in: Douglas Painter
# No valid separators found in: Gilsw
# No valid separators found in: Chuuta2003
# No valid separators found in: Gloria Tells
# No valid separators found in: Alfredito Guzman Salazar jr
# No valid separators found in: Ihor Vitsinskyy
# No valid separators found in: María Grever
# No valid separators found in: Round Hill Works
# No valid separators found in: Johnny Blaine Wilber
# No valid separators found in: Michael Nyman
# No valid separators found in: Dzũng Chinh
# No valid separators found in: Abbas Tyrewala
# No valid separators found in: Jerae Prather
# No valid separators found in: ishshon whitfield
# No valid separators found in: Amartya Rahut
# No valid separators found in: Magicbox Animation Private Limited
# No valid separators found in: AC Berkheimer
# No valid separators found in: Banyu Nugroho
# No valid separators found in: NON COPYRIGHT ELEMENT
# No valid separators found in: Fazo Steppin
# No valid separators found in: Trent Reznor
# No valid separators found in: Erik Vargas
# No valid separators found in: John Fogerty
# No valid separators found in: OH HUK
# No valid separators found in: Michael Scott Weber
# No valid separators found in: ZUN
# No valid separators found in: Devrandre Willis
# No valid separators found in: Sweet Pie Records
# No valid separators found in: Jin Lee
# No valid separators found in: TryHardNinja
# No valid separators found in: Kalyan Nayak
# No valid separators found in: Bheems Ceciroleo
# No valid separators found in: Jonathan Paes
# No valid separators found in: Vybz Kartel
# No valid separators found in: Martin Urieta
# No valid separators found in: Jeff Lew
# No valid separators found in: Abebe Birhane
# No valid separators found in: Nelson Belchior
# No valid separators found in: Himesh Reshammiya
# No valid separators found in: Morten Veland
# No valid separators found in: Nawal Khan
# No valid separators found in: Wiwik Sagita
# No valid separators found in: Jimmie Hughes
# No valid separators found in: Bruce Springsteen
# No valid separators found in: Marshall Noel
# No valid separators found in: Yng Lvcas
# No valid separators found in: 刘洲
# No valid separators found in: CA KEENER DAVID
# No valid separators found in: Davy DMX
# No valid separators found in: The Fray
# No valid separators found in: Brian May
# ...
# No valid separators found in: Kalib Markel Jackson
# No valid separators found in: BERNARD ELISABETH
# No valid separators found in: Domínio Público
# No valid separators found in: Diem Segura
# No valid separators found in: Billy Joel
# No valid separators found in: Kei
# No valid separators found in: Carl Philipp Emanuel Bach
# No valid separators found in: Antonio Vivaldi
# No valid separators found in: Nicholas Britell
# No valid separators found in: Crystal KidZ
# No valid separators found in: Michael McGregor
# No valid separators found in: Chico Buarque
# No valid separators found in: ABSTRAXION
# No valid separators found in: Ulf Lundell
# No valid separators found in: Robert Broberg
# No valid separators found in: Zachary Fira
# No valid separators found in: Mitchell Torok
# No valid separators found in: John Dwyer
# No valid separators found in: Hebron Ministries
# No valid separators found in: LUH DOODIE
# No valid separators found in: Grant Feldman
# No valid separators found in: PolyphonicBranch
# No valid separators found in: George Wallington
# No valid separators found in: Kurt Ralske
# No valid separators found in: Peter Stridh
# No valid separators found in: Neto Peña
# No valid separators found in: Harold McNeal
# No valid separators found in: Alek Soltirov
# No valid separators found in: BASS MILTON MR
# No valid separators found in: Erick Bermeo
# No valid separators found in: Lou Reed
# No valid separators found in: Pink Razors
# No valid separators found in: Arthur Sullivan
# No valid separators found in: José Antonio Ortiz Castaneda
# No valid separators found in: Sarah Albee
# No valid separators found in: Tushencov Ruslan Sergeevich
# No valid separators found in: snny
# No valid separators found in: Sam Bielanski
# No valid separators found in: Alan Notkin
# No valid separators found in: Joseph Campbell
# No valid separators found in: Angel Montolla
# No valid separators found in: Kyrylo Zaplotynskyi
# No valid separators found in: Milos Bulajic
# No valid separators found in: Michael Colina
# No valid separators found in: J
# No valid separators found in: Arun Kumar
# No valid separators found in: WELLS DEDRIC
# No valid separators found in: Clifton Haralson
# No valid separators found in: Simon Peter
# No valid separators found in: UNICHAPPELL MUSIC INC
# No valid separators found in: DJ Rasoul
# No valid separators found in: Andrii Yefymov
# No valid separators found in: Đức Huy
# No valid separators found in: Ludwig van Beethoven
# No valid separators found in: Guy Lobé
# No valid separators found in: 輕音作家
# No valid separators found in: Antonio Paul Williams
# No valid separators found in: Keenan Sun
# No valid separators found in: Our Last Night
# No valid separators found in: かめりあ
# No valid separators found in: Bernard Scott
# No valid separators found in: Adrien Gallo
# No valid separators found in: Kanonenfieber
# No valid separators found in: Derrick Reynolds
# No valid separators found in: Antoine Fafard
# No valid separators found in: Mark Knopfler
# No valid separators found in: Naomi Key
# No valid separators found in: Go Sugimoto
# No valid separators found in: Tom MacDonald
# No valid separators found in: Jocelyn Pook
# No valid separators found in: Gregory Antoine Angele Cotti
# No valid separators found in: BLP KOSHER
# No valid separators found in: Exodia
# No valid separators found in: Lynden Reese Williams
# No valid separators found in: D R A
# No valid separators found in: Pedro Guerra
# No valid separators found in: Steve Gibbons
# No valid separators found in: Antonio Henderson
# No valid separators found in: Michael Andrew Delph
# No valid separators found in: Bilma Anabel Marquez
# No valid separators found in: Quốc Vượng
# No valid separators found in: AFTRHRS
# No valid separators found in: Chuy Nuñez
# No valid separators found in: Ilaiyaraaja
# No valid separators found in: 岩井由紀
# No valid separators found in: Noah Brickley
# No valid separators found in: UNKNOWN
# No valid separators found in: Christopher Drake
# No valid separators found in: BLACKBERRY NOAH
# No valid separators found in: Nick Cave
# No valid separators found in: Adam Moyer
# No valid separators found in: Involved Publishing Ltd
# No valid separators found in: Philip Glass
# No valid separators found in: SOLIS SOSA  MARCO ANTONIO
# No valid separators found in: Reed Cleve
# No valid separators found in: Morten Veland
# No valid separators found in: Andre Wurms
# No valid separators found in: Yngwie Malmsteen
# No valid separators found in: Orhan Gül
# No valid separators found in: Mahito Yokota and Koji Kondo
# No valid separators found in: Oleksii Romanenko
# No valid separators found in: Agam Aggarwal
# No valid separators found in: David Leo Gómez
# No valid separators found in: Cornelio Reyna Cisneros
# No valid separators found in: Robert Schumann
# No valid separators found in: Wolfram Graul
# No valid separators found in: Hiroyuki Sawano and Rie Sawano
# No valid separators found in: Ard Adz
# No valid separators found in: Nick Taylor
# No valid separators found in: Daan Junior
# No valid separators found in: Pastor Samuel Ferreira
# No valid separators found in: RedOne
# No valid separators found in: Composer Unknown
# No valid separators found in: أبو فراس الحمداني
# No valid separators found in: Gilberto Martinez Tinajero
# No valid separators found in: Second
# No valid separators found in: 森田朋子
# No valid separators found in: Trần Tiến
# No valid separators found in: HSHK
# No valid separators found in: Didier Wampas
# No valid separators found in: Mikhail Zvezdinskiy
# No valid separators found in: Sanjay K
# No valid separators found in: Yuno Miles
# No valid separators found in: Notti Osama
# No valid separators found in: Neil Berry Jr
# No valid separators found in: Tankcrimes
# No valid separators found in: Eliseo Herrera
# No valid separators found in: Danni Scarpa
# No valid separators found in: Kevin L Barnes
# No valid separators found in: Michael Anthony Gricoski
# No valid separators found in: Musarrat Nasir Ji
# No valid separators found in: Felix Mendelssohn
# No valid separators found in: Martez Harrison
# No valid separators found in: Saul David Ornelas
# No valid separators found in: Nic Jones
# No valid separators found in: Paul Varney
# No valid separators found in: Germán Rosario
# No valid separators found in: 2023 Mint 400 Records
# No valid separators found in: adan rodriguez
# No valid separators found in: Bhupendra Sahu
# No valid separators found in: ADRIAN DOMINIC WALTHER
# No valid separators found in: Mc Kadu
# No valid separators found in: Gonzalo Hermosa
# No valid separators found in: Austin Farwell
# No valid separators found in: Mark Mothersbaugh
# No valid separators found in: Miklós Rózsa
# No valid separators found in: Jay Kerner
# No valid separators found in: Valdecir Marques
# No valid separators found in: Claude Debussy
# No valid separators found in: Mateo Moreno
# No valid separators found in: Ben Prokopowicz
# No valid separators found in: Макс Барских
# No valid separators found in: Dequandre Addison
# No valid separators found in: Damu Kananu
# No valid separators found in: Rajai Omar Jones
# No valid separators found in: Leonard Bernstein
# No valid separators found in: Yumi Zouma
# No valid separators found in: Diego Aceves y Carlos Zuñiga
# No valid separators found in: Boosie Badazz
# No valid separators found in: Garrett Falls Lockhart
# No valid separators found in: Legless
# No valid separators found in: Henry Purcell
# No valid separators found in: Alan Tarney
# No valid separators found in: Anup Rubens
# No valid separators found in: CAKEboy
# No valid separators found in: Slim
# No valid separators found in: Raymundo Perez Y Soto
# No valid separators found in: Ngọc Sơn
# No valid separators found in: Anthony Burgos
# No valid separators found in: Islamic Nasheed
# No valid separators found in: Oggyl lnu
# No valid separators found in: 景山将太
# No valid separators found in: Transponder
# No valid separators found in: Torath
# No valid separators found in: GARAJ
# No valid separators found in: LOTHAR NAKAT
# No valid separators found in: Antonio Pinto
# No valid separators found in: Từ Công Phụng
# No valid separators found in: Electro Media
# No valid separators found in: Leslie Bricusse
# No valid separators found in: PME Jaybee
# No valid separators found in: A Bernghein
# No valid separators found in: Enrique Fato Guzman
# No valid separators found in: Israel Romero
# No valid separators found in: Thomas Bergersen
# No valid separators found in: Angel Ivan Cerda
# No valid separators found in: Gumercindo Palacios
# No valid separators found in: Mohamed Allaoua
# No valid separators found in: Mikel Ross Giffin
# No valid separators found in: Ricky M Taylor
# No valid separators found in: Prznt
# No valid separators found in: Lionel Lueke
# No valid separators found in: Count Grishnackh
# No valid separators found in: Toby Fox
# No valid separators found in: Jordan Critz
# No valid separators found in: Pongsit Kampee
# No valid separators found in: Jose Ontiveros Meza
# No valid separators found in: Dar
# No valid separators found in: Federico Ramírez Carrasco
# No valid separators found in: Dexter Holland
# No valid separators found in: Carlinhos Brown
# No valid separators found in: Saida Karoli
# No valid separators found in: Andrés Abbadie
# No valid separators found in: Los Zultannes del Norte
# No valid separators found in: Joe Butler
# No valid separators found in: THOMAS GEORGES JACQUESTHIERRY
# No valid separators found in: Hiyakiporinekisesanamope Choir
# No valid separators found in: Liam Tadeo
# No valid separators found in: Taliyah Mccarty
# No valid separators found in: Akihiro Nishino
# No valid separators found in: Dee Thao
# No valid separators found in: Alberto Aguilera Valadez
# No valid separators found in: Paul Dinletir
# No valid separators found in: Jerry Herman
# No valid separators found in: Javonte A Williams
# No valid separators found in: Ren
# No valid separators found in: Sleep Da Danker
# No valid separators found in: Candelaria Tojin
# No valid separators found in: Noboru Mutoh
# No valid separators found in: Niki Reiser
# No valid separators found in: Alan Menken
# No valid separators found in: ピノキオピー
# No valid separators found in: Phil Collins
# No valid separators found in: Moon Byul
# No valid separators found in: DOM KENNEDY
# No valid separators found in: Conway the Machine
# No valid separators found in: Violin Valenti
# No valid separators found in: Silver Coin
# No valid separators found in: 近藤浩治
# No valid separators found in: Lil Tracy
# No valid separators found in: Justin Starling
# No valid separators found in: MIGUEL HERNANDEZ MUÑOZ
# No valid separators found in: Maciej Borowicz
# No valid separators found in: Roza Filberg
# No valid separators found in: Leonard Morris Williams II
# No valid separators found in: Giring Ganesha
# No valid separators found in: Lynn Melnikova
# No valid separators found in: Thomas Christiansen
# No valid separators found in: Marcus Clark
# No valid separators found in: Julián Alalouf
# No valid separators found in: George Bell
# No valid separators found in: BOWIE  DAVID
# No valid separators found in: Mauricio Ramos Pintado
# No valid separators found in: Muhammad Doro Shirmonov
# No valid separators found in: Dhea
# No valid separators found in: Alice Hawthorne
# No valid separators found in: Zeritu Kebede
# No valid separators found in: Tory Lanez
# No valid separators found in: Francisco Martinez
# No valid separators found in: Gabriel Fauré
# No valid separators found in: Armando Ávila
# No valid separators found in: Kalifah Aganaga
# No valid separators found in: Elisa Lindström
# No valid separators found in: Thomas Vanluvender Jr
# No valid separators found in: Lyric Ragston
# No valid separators found in: Russell Campbell
# No valid separators found in: mix yemani
# No valid separators found in: Yusef Salim
# No valid separators found in: Sam Wa Ukweli
# No valid separators found in: Oneal Callender
# No valid separators found in: Jose Luis Reyes
# No valid separators found in: Aldo Roberto Rodriguez Baquero
# No valid separators found in: DJ Drez
# No valid separators found in: Rudolf Müssig
# No valid separators found in: Otis Redding
# No valid separators found in: Marc Cantone
# No valid separators found in: Drew Eisenberg
# No valid separators found in: Not Documented
# No valid separators found in: Brandon Timothy Martin
# No valid separators found in: Alfred Newman
# No valid separators found in: JaMon Randolph
# No valid separators found in: Karen A Rontowski
# No valid separators found in: Rexx Life Raj
# No valid separators found in: Bulmaro Bermúdez
# No valid separators found in: Jim Matheos
# No valid separators found in: Barry Mason
# No valid separators found in: Lawrence Hart
# No valid separators found in: Marco Frisina
# No valid separators found in: Reginald Cousar
# No valid separators found in: Edward Mokolo
# No valid separators found in: BDOT Goon
# No valid separators found in: Xabian Oneil Woods
# No valid separators found in: Yulduz Usmonova
# No valid separators found in: Josue Barahona
# No valid separators found in: Tri Hartandi
# No valid separators found in: Artem Tymoshenko
# No valid separators found in: Nurbanu Elyaf
# No valid separators found in: BACALOV  LUIS ENRIQUE
# No valid separators found in: Juan Hidalgo
# No valid separators found in: Bentzi Marcus
# No valid separators found in: Jaylon Rhodes
# No valid separators found in: 이상웅
# No valid separators found in: Jimmy Rushing
# No valid separators found in: Alejandro Najera
# No valid separators found in: Alexandre Bueno Santa Maria
# No valid separators found in: Madison
# No valid separators found in: Kevin Rix
# No valid separators found in: Shpëtim Saraçi
# No valid separators found in: NON COPYRIGHT ELEMENT
# No valid separators found in: Patrice Eisenhardt
# No valid separators found in: Dada R Bz
# No valid separators found in: Misdam
# No valid separators found in: Pedro de Escobar
# No valid separators found in: Andreas Bruhn
# No valid separators found in: GlockBoy BoBo
# No valid separators found in: Michael Brook
# No valid separators found in: Oliver Mtukudzi
# No valid separators found in: GlockBoy BoBo
# No valid separators found in: Sean Paul Ryan Francis Henriques
# No valid separators found in: Johann Sebastian Bach
# No valid separators found in: Angel Grabiel Matos
# No valid separators found in: Arsenio Rodríguez
# No valid separators found in: Tommy Redd
# No valid separators found in: Nkosi Moyo
# No valid separators found in: Grupo Zúmbale Primo
# No valid separators found in: Ricky Ware
# No valid separators found in: George Gershwin
# No valid separators found in: Phillip Johnson
# No valid separators found in: Denial Ramic
# No valid separators found in: Josh Mancell
# No valid separators found in: Jeremy Quainton
# No valid separators found in: Brandon David Clahassey
# No valid separators found in: Cristian Orozco
# No valid separators found in: Noticuz
# No valid separators found in: Mark Suozzo
# No valid separators found in: Soen
# No valid separators found in: Duke Honcho
# No valid separators found in: Stephen Hermann
# No valid separators found in: Mellodees
# No valid separators found in: Peter Richards
# No valid separators found in: Curtis A Boyd
# No valid separators found in: Rolando Hernández Reyes
# No valid separators found in: Cafe Music BGM channel
# No valid separators found in: Suzi Analogue
# No valid separators found in: Royster Lee
# No valid separators found in: Rene Perez
# No valid separators found in: Yu Mi Lee
# No valid separators found in: Maleek Smith
# No valid separators found in: Eduardo Reyes Garcia Lopez
# No valid separators found in: Jochen Engelking
# No valid separators found in: Adán Cruz
# No valid separators found in: Hannah Lenae DeMarino
# No valid separators found in: Tammy S Keorkunian
# No valid separators found in: Gustavo Cerati
# No valid separators found in: Gabriel Stevenson
# No valid separators found in: Alliauna Green
# No valid separators found in: VCPMC
# No valid separators found in: Javier Lopez
# No valid separators found in: Matt Taylor
# No valid separators found in: Carlos Melendez
# No valid separators found in: Tsandy Rizal Adi Pradana
# No valid separators found in: Ricardo Realpe
# No valid separators found in: Tevin Kemp
# No valid separators found in: Terrance Byrd
# No valid separators found in: Pillar Point
# No valid separators found in: Sierra Lucas
# Processed data has been saved to output_file.csv

# %% [markdown]
# ## Metrics:
#
# First an quick and dirty calculation  of the average recall

# %%
import pandas as pd
import ast

# Function to split CLEAN_TEXT by '/' based on labeling convention
def split_clean_text(text):
    if not text or not isinstance(text, str):
        return []  # Handle empty or invalid inputs
    return [part.strip() for part in text.split('/') if part.strip()]

# Function to calculate accuracy
def calculate_recall(row, display=False):
    # Extract the reference and predicted lists
    reference = set(split_clean_text(row['CLEAN_TEXT']))
    phrases_list = ast.literal_eval(row['split_phrases'])  # Convert to list
    predicted = set(phrases_list)

    # Calculate metrics
    correct = len(reference & predicted)
    total = len(reference)
    acc = correct / total if total > 0 else 0
    if display:
        print('CLEAN_TEXT label:',reference,'Clean Up Prediction:', predicted,'Similarity:', acc)
    return acc

# Load the processed CSV
file_path = "output_file.csv"  
df = pd.read_csv(file_path)

# Small test ERASE
print(df.iloc[0])
calculate_recall(df.iloc[0])

# Apply the accuracy calculation for each row
df['recall'] = df.apply(calculate_recall, axis=1)

# Calculate overall accuracy
overall_accuracy = df['recall'].mean()

# Print the results
print(f"Overall Recall: {overall_accuracy * 100:.2f}%")

# Save results for review
output_with_accuracy = "output_with_accuracy.csv"
df.to_csv(output_with_accuracy, index=False)
print(f"Results with accuracy have been saved to {output_with_accuracy}")
# Out:
# raw_comp_writers_text              Jordan Riley/Adam Argyle/Martin Brammer
# CLEAN_TEXT                         Jordan Riley/Adam Argyle/Martin Brammer
# split_phrases            ['Jordan Riley', 'Adam Argyle', 'Martin Brammer']
# Name: 0, dtype: object
# Overall Recall: 73.97%
# Results with accuracy have been saved to output_with_accuracy.csv

# %% [markdown]
# ### More general evaluation:
#
# We compare the full sets of predicted and reference phrases, labeling items as 1 (present) or 0 (not present) for each set, and then computing standard classification metrics like accuracy, precision, recall, and F1-score.

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.metrics import edit_distance


# Function to split CLEAN_TEXT by '/' based on labeling convention
def split_clean_text(text):
    if not text or not isinstance(text, str):
        return []  # Handle empty or invalid inputs
    return [part.strip() for part in text.split('/') if part.strip()]

# Function to calculate BLEU score with special handling for single-token cases
def calculate_bleu(reference, predicted):
    smoothing_fn = SmoothingFunction().method1

    # If only one token, use a simple string comparison (only 2-gram+ in the implementation from nltk)
    if len(reference) == 1 and len(predicted) == 1:
        return 1.0 if reference[0] == predicted[0] else 0.0

    # Otherwise, compute BLEU score normally
    return sentence_bleu([reference], predicted, weights=(0.5, 0.5), smoothing_function=smoothing_fn)


# Function to calculate metrics per row
def calculate_metrics(row):
    # Extract the reference and predicted sets
    reference = set(split_clean_text(row['CLEAN_TEXT']))
    pred_phrases_list = ast.literal_eval(row['split_phrases'])  # Convert to list
    predicted = set(pred_phrases_list)    
    # Combine all unique phrases
    all_phrases = list(reference | predicted)
    
    # Create binary labels for reference and predicted
    reference_labels = [1 if phrase in reference else 0 for phrase in all_phrases]
    predicted_labels = [1 if phrase in predicted else 0 for phrase in all_phrases]
    
    # Compute edit distance and BLEU score
    edit_dist = edit_distance(' '.join(reference), ' '.join(predicted))
    bleu = calculate_bleu(list(reference), list(predicted))
    #print(reference,predicted, edit_dist, bleu)
    # Return the metrics
    return reference_labels, predicted_labels, all_phrases, edit_dist, bleu


# Load the processed CSV
file_path = "output_file.csv"  
df = pd.read_csv(file_path)

# Apply metrics calculation to each row
metrics = df.apply(calculate_metrics, axis=1)

# Flatten the results for global metrics computation
reference_labels = []
predicted_labels = []
all_phrases = []
edit_distances = []
bleu_scores = []

for ref, pred, phrases, edit_dist, bleu in metrics:
    reference_labels.extend(ref)
    predicted_labels.extend(pred)
    all_phrases.extend(phrases)
    edit_distances.append(edit_dist)
    bleu_scores.append(bleu)

    #for r,p,ph in zip(ref,pred, phrases):
    #    if(r==1 and p==0):
    #        print(r,p,ph,phrases)

# Calculate overall metrics
precision = precision_score(reference_labels, predicted_labels, zero_division=0)
recall = recall_score(reference_labels, predicted_labels, zero_division=0)
f1 = f1_score(reference_labels, predicted_labels, zero_division=0)

# Logging also the accuracy and CM for completion
accuracy = accuracy_score(reference_labels, predicted_labels)
cm = confusion_matrix(reference_labels, predicted_labels) # Expected 0 predicted and true negatives

# Calculate overall average metrics
avg_edit_distance = sum(edit_distances) / len(edit_distances)
avg_bleu_score = sum(bleu_scores) / len(bleu_scores)

# Print overall metrics
print(f"Accuracy: {accuracy * 100:.2f}%")
print(f"Precision: {precision * 100:.2f}%")
print(f"Recall: {recall * 100:.2f}%")
print(f"F1 Score: {f1 * 100:.2f}%")
print(f"Average Edit Distance: {avg_edit_distance:.2f}")
print(f"Average BLEU Score: {avg_bleu_score:.2f}")


# Save detailed results for debugging (optional)
output_with_details = "output_with_details.csv"
df['reference_labels'] = [ref for ref, _, _, _, _ in metrics]
df['predicted_labels'] = [pred for _, pred, _, _, _ in metrics]
df['all_phrases'] = [phrases for _, _, phrases, _, _ in metrics]
df['edit_distance'] = edit_distances
df['bleu_score'] = bleu_scores
df.to_csv(output_with_details, index=False)
print(f"Detailed results with edit distance and BLEU score have been saved to {output_with_details}")
# Out:
# Accuracy: 57.91%
# Precision: 65.99%
# Recall: 82.54%
# F1 Score: 73.34%
# Average Edit Distance: 7.24
# Average BLEU Score: 0.70
# Detailed results with edit distance and BLEU score have been saved to output_with_details.csv

# %% [markdown]
# Accuracy: 57.91%
# Precision: 65.99%
# Recall: 82.54%
# F1 Score: 73.34%
# CM:
# [[    0  7463]
#  [ 3064 14482]]
# Detailed results have been saved to output_with_details.csv
#
# The current  model is biased toward predicting positives (since the)
#
#
# Strong:
# Accuracy: 57.91%
# Precision: 65.99%
# Recall: 82.54%
# F1 Score: 73.34%
# Average Edit Distance: 7.24
# Average BLEU Score: 0.70
#
#
# Weak:
# Accuracy: 67.63%
# Precision: 74.86%
# Recall: 87.51%
# F1 Score: 80.69%
# Average Edit Distance: 6.37
# Average BLEU Score: 0.76
# Detailed results with edit distance and BLEU score have been saved to output_with_details.csv

# %% [markdown]
# Note: If we want to run things faster switch to

# %% [markdown]
# ### Basic LLM Implementation:
#
# Initial experimentation

# %%
from groq import Groq

client = Groq(
    api_key="",
)

# We create the prompt includings
phrase= "DJ PALEMBANG/Copyright Control"
prompt = \
f"""
You are a useful linguist assistant. We want to perform text normalisation on names of songwriters. We will give you a string which includes names or nicknames 
in different formats and containing potentially unecessary words you ll need to clean up - or maybe just the name or nickname. 
Also some Raw text does not contain any useful information (e.g., unknown, weird initials, standardized words, etc)
Do not include any outputs of non-latin (e.g., cyrillic, chinese or arabian) characters in your output. If there are multiple names or nicknames separate with '/'
You ll need to return the correct names.
Some examples:
Example1:
RAW TEXT: <Unknown>/Wright, Justyce Kaseem
Normalized Text: Justyce Kaseem Wright
Example 2:
RAW TEXT: Pixouu/Abdou Gambetta/Copyright Control
Normalized Text: Pixouu/Abdou Gambetta
Example 3:
RAW TEXT: Mike Hoyer/JERRY CHESNUT/SONY/ATV MUSIC PUBLISHING (UK) LIMITED
Normalized Text: JERRY CHESNUT/Mike Hoyer
Example 4:
RAW TEXT: 신중현 (Shin Joong Hyun)
Normalized Text: Shin Joong Hyun
Example 5:
RAW TEXT: 신중현
Normalized Text:
Example 6:
RAW TEXT: UNKNOWN 
Normalized Text: 

Perform the same for the following cases:
RAW TEXT:{phrase}
RAW TEXT: Аршавир Мартиросян
RAW TEXT: Yuvanshankar Raja & Ramajogayya Sastry
RAW TEXT: jdiocsjiofouefan
"""
print(prompt)
###  Output (we can easily extract the normalized names): #########
#Here are the results of the text normalization:
#
#1. RAW TEXT: DJ PALEMBANG/Copyright Control
#Normalized Text: DJ PALEMBANG
#
#2. RAW TEXT: Аршавир Мартиросян
#Normalized Text: (since the text contains non-Latin characters, I'll leave the field empty)
#
#3. RAW TEXT: Yuvanshankar Raja & Ramajogayya Sastry
#Normalized Text: Yuvanshankar Raja/Ramajogayya Sastry
#
#4. RAW TEXT: jdiocsjiofouefan
#Normalized Text: (since the text appears to be nonsense and doesn't contain any useful information)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": prompt,
        }
    ],
    model="llama3-8b-8192",
)
print(chat_completion.choices[0].message.content)
